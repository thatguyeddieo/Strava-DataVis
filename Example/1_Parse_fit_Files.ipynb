# %% [markdown]
# ## Introduction

# %% [markdown]
# There are several ways for exporting your Strava activities. We recommend bulk exporting all your Strava data. This example assumes a bulk export archive was downloaded and saved to a local directory. For more information on how to export your Strava data [see these instruction from Strava Support](https://support.strava.com/hc/en-us/articles/216918437-Exporting-your-Data-and-Bulk-Export#Bulk).

# %%
import os
import pandas as pd

# %%
bulk_strava_dir = "~/Desktop/strava_data"

# %% [markdown]
# Your activities meta data can be found in **activities.csv** at the root of your bulk data export. While the activities directory contains the detailed FIT (Flexible and Interoperable Data Transfer) datafile.

# %% [markdown]
# Load metadata and inspect contents

# %%
df = pd.read_csv(os.path.join(bulk_strava_dir,"activities.csv"))
df.head()
# Out:
#    Activity ID             Activity Date   Activity Name Activity Type  \
# 0    363761300  Aug 7, 2015, 11:30:54 PM    Evening Ride          Ride
# 1    372131020  Aug 18, 2015, 9:19:19 PM  Afternoon Ride          Ride
# 2    372140928  Aug 18, 2015, 9:40:37 PM   Afternoon Run           Run
# 3    372159226  Aug 18, 2015, 9:59:10 PM  Afternoon Ride          Ride
# 4    374254173  Aug 21, 2015, 4:27:39 PM      Lunch Ride          Ride
#
#   Activity Description  Elapsed Time  Distance  Max Heart Rate  \
# 0                  NaN          8537     46.81             NaN
# 1                  NaN          1112      5.97             NaN
# 2                  NaN           965      2.23             NaN
# 3                  NaN          2253     12.34             NaN
# 4                  NaN          8723     20.33             NaN
#
#    Relative Effort  Commute  ... Weather Ozone  \
# 0              NaN    False  ...           NaN
# 1              NaN    False  ...           NaN
# 2              NaN    False  ...           NaN
# 3              NaN    False  ...           NaN
# 4              NaN    False  ...           NaN
#
#   <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                                NaN
# 3                                           0.000000
# 4                                         218.399994
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.sport_type">Sport Type</span>
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 84 columns]

# %% [markdown]
# ## Filtering Data

# %% [markdown]
# The bulk export contains all Strava activities recorded. For this example, consider only cycling events and ranging from 2020-02-10 to 2021-05-23. To make filtering the DataFrame easier convert the "Activity Date" column to Datetime type.

# %%
begin_date, end_date = "2020-02-10", "2021-05-23"
activity_type = "Ride"

# Convert
df["Activity Date"] = pd.to_datetime(df["Activity Date"])

# %%
filter_df = df[(df["Activity Date"] > begin_date) & 
               (df["Activity Date"] < end_date) & 
               (df["Activity Type"] == activity_type)]
filter_df.head()
# Out:
#      Activity ID       Activity Date   Activity Name Activity Type  \
# 642   3129090697 2020-02-24 20:23:38       Test Ride          Ride
# 643   3163789236 2020-03-08 00:10:39  Afternoon Ride          Ride
# 644   3167419826 2020-03-08 23:14:45  Afternoon Ride          Ride
# 645   3170057800 2020-03-09 23:29:08  Afternoon Ride          Ride
# 646   3178607939 2020-03-12 23:21:11  Afternoon Ride          Ride
#
#     Activity Description  Elapsed Time  Distance  Max Heart Rate  \
# 642                  NaN          1719      9.03           146.0
# 643                  NaN          4937     19.54           165.0
# 644                  NaN          7805     40.45           170.0
# 645                  NaN          9113     50.76           175.0
# 646                  NaN          7966     43.76           170.0
#
#      Relative Effort  Commute  ... Weather Ozone  \
# 642              7.0    False  ...           NaN
# 643             31.0    False  ...           NaN
# 644             70.0    False  ...           NaN
# 645             97.0    False  ...           NaN
# 646            103.0    False  ...           NaN
#
#     <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>  \
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>  \
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>  \
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>  \
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>  \
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>  \
# 642                                                0.0
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>  \
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>  \
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.sport_type">Sport Type</span>
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
#
# [5 rows x 84 columns]

# %% [markdown]
# Compare number of activities found within specified date range

# %%
len(df)
# Out:
# 981

# %%
len(filter_df)
# Out:
# 148

# %% [markdown]
# ## Parse Data

# %%
import glob

# %% [markdown]
# The FIT files in the activities directory should match the activity ID. However, sometimes the 'Activity ID' column and activity filename do not line up. Ensure the correct activity FIT file is parsed by reading the 'Filename' column instead.

# %%
activity_filenames = filter_df['Filename']
activity_filenames.head()
# Out:
# 642    activities/3342746054.fit.gz
# 643    activities/3381305871.fit.gz
# 644    activities/3385302851.fit.gz
# 645    activities/3388256403.fit.gz
# 646    activities/3397678888.fit.gz
# Name: Filename, dtype: object

# %% [markdown]
# Import Strava-DataVis modules

# %%
from formats import parseFile
from formats import formats

# %% [markdown]
# Create Python dictionary data structure template. See the [Strava-DataVis](https://thatguyeddieo.github.io/Strava-DataVis/formats.html) ``formats`` documentation for page for more information on the dictionary structure.

# %%
strava_data = formats.create_datastruct()

# %% [markdown]
# Create a list of filenames and parse individual fit.gz files

# %%
fit_paths = [os.path.expanduser('~/Desktop/strava_data/' + a) for a in activity_filenames]

# %%
# Parse fit files of interest
for file in fit_paths:
    parseFile.parse(strava_data,file);
# Out:
# Parsing ~/.../3342746054.fit.gz
# Parsing ~/.../3381305871.fit.gz
# Parsing ~/.../3385302851.fit.gz
# Parsing ~/.../3388256403.fit.gz
# Parsing ~/.../3397678888.fit.gz
# Parsing ~/.../3410342152.fit.gz
# Parsing ~/.../3417012319.fit.gz
# Parsing ~/.../3420132646.fit.gz
# Parsing ~/.../3423242116.fit.gz
# Parsing ~/.../3430723356.fit.gz
# Parsing ~/.../3441153174.fit.gz
# Parsing ~/.../3456862746.fit.gz
# Parsing ~/.../3480735937.fit.gz
# Parsing ~/.../3485732942.fit.gz
# Parsing ~/.../3490211937.fit.gz
# Parsing ~/.../3495267665.fit.gz
# Parsing ~/.../3499648535.fit.gz
# Parsing ~/.../3508784683.fit.gz
# Parsing ~/.../3518644149.fit.gz
# Parsing ~/.../3527816940.fit.gz
# Parsing ~/.../3537904807.fit.gz
# Parsing ~/.../3542379714.fit.gz
# Parsing ~/.../3557969094.fit.gz
# Parsing ~/.../3589532643.fit.gz
# Parsing ~/.../3594941050.fit.gz
# Parsing ~/.../3626718043.fit.gz
# Parsing ~/.../3638095333.fit.gz
# Parsing ~/.../3655153766.fit.gz
# Parsing ~/.../3661269383.fit.gz
# Parsing ~/.../3682625954.fit.gz
# Parsing ~/.../3705655591.fit.gz
# Parsing ~/.../3738995307.fit.gz
# Parsing ~/.../3756546812.fit.gz
# Parsing ~/.../3770596470.fit.gz
# Parsing ~/.../3772523804.fit.gz
# Parsing ~/.../3773019134.fit.gz
# Parsing ~/.../3827312512.fit.gz
# Parsing ~/.../3839190896.fit.gz
# Parsing ~/.../3844321360.fit.gz
# Parsing ~/.../3877507093.fit.gz
# Parsing ~/.../3887246769.fit.gz
# Parsing ~/.../3892981894.fit.gz
# Parsing ~/.../3898953352.fit.gz
# Parsing ~/.../3904046114.fit.gz
# Parsing ~/.../3920456511.fit.gz
# Parsing ~/.../3920670449.fit.gz
# Parsing ~/.../3936357784.fit.gz
# Parsing ~/.../3962013466.fit.gz
# Parsing ~/.../3972879533.fit.gz
# Parsing ~/.../3992273295.fit.gz
# Parsing ~/.../3998798719.fit.gz
# Parsing ~/.../4010839595.fit.gz
# Parsing ~/.../4016028360.fit.gz
# Parsing ~/.../4037630000.fit.gz
# Parsing ~/.../4048922764.fit.gz
# Parsing ~/.../4060787081.fit.gz
# Parsing ~/.../4081992168.fit.gz
# Parsing ~/.../4097616430.fit.gz
# Parsing ~/.../4114636033.fit.gz
# Parsing ~/.../4158311431.fit.gz
# Parsing ~/.../4169034453.fit.gz
# Parsing ~/.../4177917131.fit.gz
# Parsing ~/.../4179929130.fit.gz
# Parsing ~/.../4205465791.fit.gz
# Parsing ~/.../4220049444.fit.gz
# Parsing ~/.../4236163930.fit.gz
# Parsing ~/.../4240890864.fit.gz
# Parsing ~/.../4251046816.fit.gz
# Parsing ~/.../4255878581.fit.gz
# Parsing ~/.../4280744005.fit.gz
# Parsing ~/.../4285704372.fit.gz
# Parsing ~/.../4295201211.fit.gz
# Parsing ~/.../4300729868.fit.gz
# Parsing ~/.../4311274630.fit.gz
# Parsing ~/.../4376652014.fit.gz
# Parsing ~/.../4397090223.fit.gz
# Parsing ~/.../4405369691.fit.gz
# Parsing ~/.../4420257659.fit.gz
# Parsing ~/.../4429831988.fit.gz
# Parsing ~/.../4443391461.fit.gz
# Parsing ~/.../4471145732.fit.gz
# Parsing ~/.../4480332251.fit.gz
# Parsing ~/.../4489984351.fit.gz
# Parsing ~/.../4503027519.fit.gz
# Parsing ~/.../4517617298.fit.gz
# Parsing ~/.../4522099430.fit.gz
# Parsing ~/.../4544696716.fit.gz
# Parsing ~/.../4553718120.fit.gz
# Parsing ~/.../4566934603.fit.gz
# Parsing ~/.../4576879074.fit.gz
# Parsing ~/.../4576881732.fit.gz
# Parsing ~/.../4601512738.fit.gz
# Parsing ~/.../4613142539.fit.gz
# Parsing ~/.../4623531290.fit.gz
# Parsing ~/.../4644072861.fit.gz
# Parsing ~/.../4679180260.fit.gz
# Parsing ~/.../4693624957.fit.gz
# Parsing ~/.../4707850858.fit.gz
# Parsing ~/.../4707851982.fit.gz
# Parsing ~/.../4707852249.fit.gz
# Parsing ~/.../4717572002.fit.gz
# Parsing ~/.../4722274317.fit.gz
# Parsing ~/.../4726916355.fit.gz
# Parsing ~/.../4779470308.fit.gz
# Parsing ~/.../4815022677.fit.gz
# Parsing ~/.../4842184944.fit.gz
# Parsing ~/.../4893009568.fit.gz
# Parsing ~/.../4893009776.fit.gz
# Parsing ~/.../4931366366.fit.gz
# Parsing ~/.../4959962163.fit.gz
# Parsing ~/.../4966006692.fit.gz
# Parsing ~/.../4966008517.fit.gz
# 	Warning: Parameter altitude was not populated with data.
# 	Warning: Parameter speed was not populated with data.
# Parsing ~/.../4976396321.fit.gz
# Parsing ~/.../4987636679.fit.gz
# Parsing ~/.../4999074354.fit.gz
# Parsing ~/.../5005775541.fit.gz
# Parsing ~/.../5050047014.fit.gz
# Parsing ~/.../5073150568.fit.gz
# Parsing ~/.../5204216773.fit.gz
# Parsing ~/.../5204220670.fit.gz
# Parsing ~/.../5204224388.fit.gz
# Parsing ~/.../5265013411.fit.gz
# Parsing ~/.../5375397346.fit.gz
# Parsing ~/.../5375398506.fit.gz
# Parsing ~/.../5375399058.fit.gz
# Parsing ~/.../5376302135.fit.gz
# Parsing ~/.../5400143657.fit.gz
# Parsing ~/.../5418838834.fit.gz
# Parsing ~/.../5430651051.fit.gz
# Parsing ~/.../5449225015.fit.gz
# Parsing ~/.../5467236027.fit.gz
# Parsing ~/.../5478086145.fit.gz
# Parsing ~/.../5484706069.fit.gz
# Parsing ~/.../5491300313.fit.gz
# Parsing ~/.../5503733986.fit.gz
# Parsing ~/.../5509998833.fit.gz
# Parsing ~/.../5515738398.fit.gz
# Parsing ~/.../5534295526.fit.gz
# Parsing ~/.../5546474446.fit.gz
# Parsing ~/.../5558275007.fit.gz
# Parsing ~/.../5576040918.fit.gz
# Parsing ~/.../5592850205.fit.gz
# Parsing ~/.../5608805701.fit.gz
# Parsing ~/.../5621378213.fit.gz
# Parsing ~/.../5627267401.fit.gz
# Parsing ~/.../5696099612.fit.gz
# Parsing ~/.../6055756545.fit.gz
# Parsing ~/.../6055756543.fit.gz

# %% [markdown]
# One activity did not have any altitude or speed data.
# ```
# Parsing ~/.../4966008517.fit.gz
# 	Warning: Parameter altitude was not populated with data.
# 	Warning: Parameter speed was not populated with data.
# ```
# I decided to remove it from the dataset after reviewing the activity from my Strava App and determining it was not needed.

# %%
del(strava_data['activities']['4966008517'])

# %% [markdown]
# ## Save Parsed Data

# %% [markdown]
# Creates a new directory and export parsed activities as an Excel file for easier use later.

# %%
# write out to folder
out_dir = "datasets/Seattle_Dataset"    
formats.write_xlsx(strava_data,out_dir)
# Out:
# Writing to /datasets/Seattle_Dataset/activities.xlsx
# 	Writing activity 3342746054
# 	Writing activity 3381305871
# 	Writing activity 3385302851
# 	Writing activity 3388256403
# 	Writing activity 3397678888
# 	Writing activity 3410342152
# 	Writing activity 3417012319
# 	Writing activity 3420132646
# 	Writing activity 3423242116
# 	Writing activity 3430723356
# 	Writing activity 3441153174
# 	Writing activity 3456862746
# 	Writing activity 3480735937
# 	Writing activity 3485732942
# 	Writing activity 3490211937
# 	Writing activity 3495267665
# 	Writing activity 3499648535
# 	Writing activity 3508784683
# 	Writing activity 3518644149
# 	Writing activity 3527816940
# 	Writing activity 3537904807
# 	Writing activity 3542379714
# 	Writing activity 3557969094
# 	Writing activity 3589532643
# 	Writing activity 3594941050
# 	Writing activity 3626718043
# 	Writing activity 3638095333
# 	Writing activity 3655153766
# 	Writing activity 3661269383
# 	Writing activity 3682625954
# 	Writing activity 3705655591
# 	Writing activity 3738995307
# 	Writing activity 3756546812
